# %%
import json
import pymongo
import pandas as pd

# %%
client = pymongo.MongoClient("")
db = client.cov
records_tb = db.ventilator_live
list_of_records = list(records_tb.find({},{'_id': False}).sort("_id",-1).limit(10000))
#list_of_records = [record['0'] for record in list_of_records]

# %%
with open('data.json', 'w', encoding='utf-8') as f:
    json.dump(list_of_records, f, ensure_ascii=False, indent=4)

# %%
list_of_records[0]
# Out:
# {'0': {'device_id': 4242,
#   'processed': {'ExpiredCO2': 4.78,
#    'ExpiredO2': 40.32,
#    'FiO2': 20.4,
#    'IE': 1.3,
#    'MVe': 6345,
#    'PEEP': 0,
#    'RR': 15,
#    'VT': 400,
#    'flowrate': -4532,
#    'frequency': 10,
#    'humidity': 70.5,
#    'pressure': 1,
#    'triggerSettings': {'FiO2': 20,
#     'IE': 1.3,
#     'MVe': 6000,
#     'PEEP': 0,
#     'RR': 15,
#     'VT': 400,
#     'humidity': 70,
#     'pressure_max': 10},
#    'ventilationMode': 'Flowrate Control',
#    'volumePerMinute': 2200,
#    'volumePerMovement': 220},
#   'raw': {'CO2': 4.78,
#    'O2': 40.32,
#    'angleSensor': 320,
#    'current': 50,
#    'motorRPM': 100,
#    'pressure1': 48,
#    'pressure2': 109,
#    'temperature1': 30.08,
#    'temperature2': 32.71},
#   'time': 1587238538},
#  '1': {'device_id': 3089,
#   'processed': {'ExpiredCO2': 4.85,
#    'ExpiredO2': 40.65,
#    'FiO2': 19.65,
#    'IE': 1.3,
#    'MVe': 6345,
#    'PEEP': 0,
#    'RR': 15,
#    'VT': 400,
#    'flowrate': -2074,
#    'frequency': 10,
#    'humidity': 66.71,
#    'pressure': 1,
#    'triggerSettings': {'FiO2': 20,
#     'IE': 1.3,
#     'MVe': 6000,
#     'PEEP': 0,
#     'RR': 15,
#     'VT': 400,
#     'humidity': 70,
#     'pressure_max': 10},
#    'ventilationMode': 'Flowrate Control',
#    'volumePerMinute': 2200,
#    'volumePerMovement': 220},
#   'raw': {'CO2': 4.85,
#    'O2': 40.65,
#    'angleSensor': 320,
#    'current': 50,
#    'motorRPM': 100,
#    'pressure1': 43,
#    'pressure2': 86,
#    'temperature1': 30.84,
#    'temperature2': 27.68},
#   'time': 1587238538},
#  '2': {'device_id': 12693,
#   'processed': {'ExpiredCO2': 4.76,
#    'ExpiredO2': 37.79,
#    'FiO2': 19.99,
#    'IE': 1.3,
#    'MVe': 6345,
#    'PEEP': 0,
#    'RR': 15,
#    'VT': 400,
#    'flowrate': -3112,
#    'frequency': 10,
#    'humidity': 70.38,
#    'pressure': 1,
#    'triggerSettings': {'FiO2': 20,
#     'IE': 1.3,
#     'MVe': 6000,
#     'PEEP': 0,
#     'RR': 15,
#     'VT': 400,
#     'humidity': 70,
#     'pressure_max': 10},
#    'ventilationMode': 'Flowrate Control',
#    'volumePerMinute': 2200,
#    'volumePerMovement': 220},
#   'raw': {'CO2': 4.76,
#    'O2': 37.79,
#    'angleSensor': 320,
#    'current': 50,
#    'motorRPM': 100,
#    'pressure1': 45,
#    'pressure2': 94,
#    'temperature1': 30.29,
#    'temperature2': 29.51},
#   'time': 1587238538},
#  '3': {'device_id': 93,
#   'processed': {'ExpiredCO2': 4.79,
#    'ExpiredO2': 37.39,
#    'FiO2': 19.86,
#    'IE': 1.3,
#    'MVe': 0,
#    'PEEP': 0,
#    'RR': 15,
#    'VT': 400,
#    'flowrate': -1669,
#    'frequency': 10,
#    'humidity': 70.7,
#    'pressure': 1,
#    'triggerSettings': {'FiO2': 20,
#     'IE': 1.3,
#     'MVe': 6000,
#     'PEEP': 0,
#     'RR': 15,
#     'VT': 400,
#     'humidity': 70,
#     'pressure_max': 10},
#    'ventilationMode': 'Flowrate Control',
#    'volumePerMinute': 2200,
#    'volumePerMovement': 220},
#   'raw': {'CO2': 4.79,
#    'O2': 37.39,
#    'angleSensor': 320,
#    'current': 50,
#    'motorRPM': 100,
#    'pressure1': 371,
#    'pressure2': 97,
#    'temperature1': 34.15,
#    'temperature2': 26.37},
#   'time': 1587238538},
#  '4': {'device_id': 586,
#   'processed': {'ExpiredCO2': 5.15,
#    'ExpiredO2': 39.82,
#    'FiO2': 19.93,
#    'IE': 1.3,
#    'MVe': 6345,
#    'PEEP': 0,
#    'RR': 15,
#    'VT': 400,
#    'flowrate': 5173,
#    'frequency': 10,
#    'humidity': 68.01,
#    'pressure': 1,
#    'triggerSettings': {'FiO2': 20,
#     'IE': 1.3,
#     'MVe': 6000,
#     'PEEP': 0,
#     'RR': 15,
#     'VT': 400,
#     'humidity': 70,
#     'pressure_max': 10},
#    'ventilationMode': 'Flowrate Control',
#    'volumePerMinute': 2200,
#    'volumePerMovement': 220},
#   'raw': {'CO2': 5.15,
#    'O2': 39.82,
#    'angleSensor': 320,
#    'current': 50,
#    'motorRPM': 100,
#    'pressure1': 334,
#    'pressure2': 152,
#    'temperature1': 28.72,
#    'temperature2': 28.15},
#   'time': 1587238538}}

# %%
with open('data.json') as vent_data:
    records = json.load(vent_data)

# %%
df = pd.DataFrame()
for j in range(len(records)):
    data = records[j]
    for i in range(5):
        a = pd.Series(data[str(i)]['device_id'], name='Device_id')
        b = pd.Series(data[str(i)]['time'], name='TimeStamp')
        c = pd.DataFrame(data[str(i)]['processed'], index=[0]).drop(columns='triggerSettings')
        d = pd.DataFrame(data[str(i)]['processed']['triggerSettings'], index=[0])
        e = pd.DataFrame(data[str(i)]['raw'], index=[0])
        # pd.concat([a, b, c, d, e], axis=1)
        df = pd.concat([df, pd.concat([a, b, c, d, e], axis=1)])
df.to_csv('json_to_dataframe_new.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-0f413e04b338> in <module>
#       9         e = pd.DataFrame(data[str(i)]['raw'], index=[0])
#      10         # pd.concat([a, b, c, d, e], axis=1)
# ---> 11         df = pd.concat([df, pd.concat([a, b, c, d, e], axis=1)])
#      12 df.to_csv('json_to_dataframe_new.csv')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     279         verify_integrity=verify_integrity,
#     280         copy=copy,
# --> 281         sort=sort,
#     282     )
#     283
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     450         self.copy = copy
#     451
# --> 452         self.new_axes = self._get_new_axes()
#     453
#     454     def get_result(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in _get_new_axes(self)
#     515         return [
#     516             self._get_concat_axis() if i == self.axis else self._get_comb_axis(i)
# --> 517             for i in range(ndim)
#     518         ]
#     519
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in <listcomp>(.0)
#     515         return [
#     516             self._get_concat_axis() if i == self.axis else self._get_comb_axis(i)
# --> 517             for i in range(ndim)
#     518         ]
#     519
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in _get_concat_axis(self)
#     564
#     565         if self.keys is None:
# --> 566             concat_axis = _concat_indexes(indexes)
#     567         else:
#     568             concat_axis = _make_concat_multiindex(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in _concat_indexes(indexes)
#     585
#     586 def _concat_indexes(indexes) -> Index:
# --> 587     return indexes[0].append(indexes[1:])
#     588
#     589
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in append(self, other)
#    3988         name = None if len(names) > 1 else self.name
#    3989
# -> 3990         return self._concat(to_concat, name)
#    3991
#    3992     def _concat(self, to_concat, name):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in _concat(self, to_concat, name)
#    3995
#    3996         if len(typs) == 1:
# -> 3997             return self._concat_same_dtype(to_concat, name=name)
#    3998         return Index._concat_same_dtype(self, to_concat, name=name)
#    3999
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in _concat_same_dtype(self, to_concat, name)
#    4020         to_concat = [x._values if isinstance(x, Index) else x for x in to_concat]
#    4021
# -> 4022         return self._shallow_copy_with_infer(np.concatenate(to_concat), **attribs)
#    4023
#    4024     def putmask(self, mask, value):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in _shallow_copy_with_infer(self, values, **kwargs)
#     565             except (TypeError, ValueError):
#     566                 pass
# --> 567         return Index(values, **attributes)
#     568
#     569     def _update_inplace(self, result, **kwargs):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in __new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     314
#     315         elif (
# --> 316             is_datetime64_any_dtype(data)
#     317             or is_datetime64_any_dtype(dtype)
#     318             or "tz" in kwargs
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/common.py in is_datetime64_any_dtype(arr_or_dtype)
#    1022     if arr_or_dtype is None:
#    1023         return False
# -> 1024     return is_datetime64_dtype(arr_or_dtype) or is_datetime64tz_dtype(arr_or_dtype)
#    1025
#    1026
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/common.py in is_datetime64_dtype(arr_or_dtype)
#     398     """
#     399
# --> 400     return _is_dtype_type(arr_or_dtype, classes(np.datetime64))
#     401
#     402
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/common.py in _is_dtype_type(arr_or_dtype, condition)
#    1725
#    1726     # fastpath
# -> 1727     if isinstance(arr_or_dtype, np.dtype):
#    1728         return condition(arr_or_dtype.type)
#    1729     elif isinstance(arr_or_dtype, type):
#
# KeyboardInterrupt:
